# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 17.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 77.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 50.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
data =pd.read_csv("/content/airport_management_dataset.csv")
data.head()
data.describe
# Out:
# <bound method NDFrame.describe of      Departure Arrival   Time        Date  Terminal
# 0        CityC   CityG  09:13  2023-09-11         3
# 1        CityE   CityG  03:10  2023-09-11         3
# 2        CityC   CityH  09:58  2023-09-11         1
# 3        CityB   CityH  04:30  2023-09-11         2
# 4        CityA   CityH  04:42  2023-09-11         2
# ...        ...     ...    ...         ...       ...
# 3587     CityA   CityG  19:59  2024-09-09         2
# 3588     CityE   CityJ  07:08  2024-09-09         2
# 3589     CityC   CityF  17:07  2024-09-09         2
# 3590     CityE   CityI  00:03  2024-09-09         1
# 3591     CityA   CityI  02:08  2024-09-09         3
#
# [3592 rows x 5 columns]>

# %%
from pycaret.classification import *
clf1 = setup(data=data, target='Terminal', session_id=42)
# Out:
# <style type="text/css">
# #T_b00e8_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b00e8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b00e8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b00e8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b00e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b00e8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b00e8_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_b00e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b00e8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b00e8_row1_col1" class="data row1 col1" >Terminal</td>
#     </tr>
#     <tr>
#       <th id="T_b00e8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_60658 th {
#   text-align: left;
# }
# ...

# %%
lda = create_model('lda')
# Out:
# <style type="text/css">
# #T_cf8b1_row10_col0, #T_cf8b1_row10_col1, #T_cf8b1_row10_col2, #T_cf8b1_row10_col3, #T_cf8b1_row10_col4, #T_cf8b1_row10_col5, #T_cf8b1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_cf8b1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf8b1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_cf8b1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_cf8b1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_cf8b1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_cf8b1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_cf8b1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_cf8b1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lda = tune_model(lda)
# Out:
# <style type="text/css">
# #T_d6a4c_row10_col0, #T_d6a4c_row10_col1, #T_d6a4c_row10_col2, #T_d6a4c_row10_col3, #T_d6a4c_row10_col4, #T_d6a4c_row10_col5, #T_d6a4c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d6a4c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6a4c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d6a4c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d6a4c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d6a4c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d6a4c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d6a4c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d6a4c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_lda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
final_lda = finalize_model(tuned_lda)

# %%
save_model(final_lda, 'lda')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=[],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbo...
# ...

# %% [markdown]
# # New Section
